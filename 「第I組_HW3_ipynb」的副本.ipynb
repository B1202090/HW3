# %%
print("I'm a student")
# Out:
# I'm a student

# %%
a = int(input('請輸入x1='))
b = int(input('請輸入y1='))
c = int(input('請輸入x2='))

d = int(input('請輸入y2='))

a -= c

b -= d

print('AB距離=',((a**2+b**2)**(1/2)))
# Out:
# 請輸入x1=0
# 請輸入y1=0
# 請輸入x2=3
# 請輸入y2=4
# AB距離= 5.0

# %%
a = int(input('身高為(cm)'))
b = int(input('體重為(kg)'))
b /= 0.01*a
print(int(b<18.5))
# Out:
# 身高為(cm)147
# 體重為(kg)39
# 1
